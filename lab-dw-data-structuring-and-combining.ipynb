# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Import pandas and load dfs

import pandas as pd

# Load customer data dataset an from an insurance company
url1 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
customer_df1 = pd.read_csv(url1)
customer_df1.head(2)

# Load file 2 from an insurance company
url2 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
customer_df2 = pd.read_csv(url2)
customer_df2.head(2)

# Load file 3 from an insurance company
url3 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'
customer_df3 = pd.read_csv(url3)
customer_df3.head(2)

# Define how floats are formatted when displayed with the string formatting function: '{:,.2f}'.format
# , → adds a thousands separator (e.g., 1,000 instead of 1000)
# .2f → rounds numbers to two decimal places
pd.options.display.float_format = '{:,.2f}'.format

# %%
customer_df1.head(2)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  RB50392  Washington    NaN    Master                     NaN    0.00
# 1  QZ44356     Arizona      F  Bachelor              697953.59%    0.00
#
#    Monthly Premium Auto Number of Open Complaints    Policy Type  \
# 0              1,000.00                    1/0/00  Personal Auto
# 1                 94.00                    1/0/00  Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car                2.70
# 1  Four-Door Car            1,131.46

# %%
customer_df2.head(2)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00              633.60
# 1                   114                    1/0/00              547.20
#
#      Policy Type  Vehicle Class
# 0  Personal Auto  Four-Door Car
# 1   Special Auto            SUV

# %%
customer_df3.head(2)
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington                 3,479.14  High School or Below      M
# 1  TB86706     Arizona                 2,502.64                Master      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
#
#    Total Claim Amount Vehicle Class
# 0              499.20  Two-Door Car
# 1                3.47  Two-Door Car

# %% [markdown]
# #### Check shape, types and nulls of each df
#  First combine the three datasets and then apply the cleaning function to the new combined dataset

# %%
customer_df1.shape
# Out:
# (4008, 11)

# %%
#Check the type of the variables of the df
customer_df1.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
customer_df1.isna().sum()
# Out:
# Customer                     2937
# ST                           2937
# GENDER                       3054
# Education                    2937
# Customer Lifetime Value      2940
# Income                       2937
# Monthly Premium Auto         2937
# Number of Open Complaints    2937
# Policy Type                  2937
# Vehicle Class                2937
# Total Claim Amount           2937
# dtype: int64

# %%
customer_df2.shape
# Out:
# (996, 11)

# %%
#Check the type of the variables of the df
customer_df2.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints     object
# Total Claim Amount           float64
# Policy Type                   object
# Vehicle Class                 object
# dtype: object

# %%
customer_df2.isna().sum()
# Out:
# Customer                     0
# ST                           0
# GENDER                       5
# Education                    0
# Customer Lifetime Value      4
# Income                       0
# Monthly Premium Auto         0
# Number of Open Complaints    0
# Total Claim Amount           0
# Policy Type                  0
# Vehicle Class                0
# dtype: int64

# %%
customer_df3.shape
# Out:
# (7070, 11)

# %%
# Check the type of the variables of the df
customer_df3.dtypes
# Out:
# Customer                      object
# State                         object
# Customer Lifetime Value      float64
# Education                     object
# Gender                        object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints      int64
# Policy Type                   object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object

# %%
customer_df3.isna().sum()
# Out:
# Customer                     0
# State                        0
# Customer Lifetime Value      0
# Education                    0
# Gender                       0
# Income                       0
# Monthly Premium Auto         0
# Number of Open Complaints    0
# Policy Type                  0
# Total Claim Amount           0
# Vehicle Class                0
# dtype: int64

# %% [markdown]
# #### Prepare the df for the concatenation by standardise col names and format the data

# %%
# Normalize text columns (strip spaces, set lowercase)

# Parameters:
# df : DataFrame
# cols : columns to normalize; if None, all object/string columns
# lower : convert to lowercase
# strip : strip leading/trailing whitespace
# normalize_columns: normalize column names (strip, lower, replace spaces with _)

# Returns:
# DataFrame (same object, modified in place style but returns df for chaining)


from typing import Optional, Iterable
def standardize_text(
    df: pd.DataFrame,
    cols: Optional[Iterable[str]] = None,
    lower: bool = True,
    strip: bool = True,
    normalize_columns: bool = True,
) -> pd.DataFrame:
       
# Standardizing string values (inside the cells)
    if cols is None:
        cols = df.select_dtypes(include=["object", "string"]).columns  # all object/string columns
    for c in cols:
        s = df[c].astype("string")  # ensure string dtype
        if strip:
            s = s.str.strip()  # removes leading/trailing spaces
        if lower:
            s = s.str.lower()  # convert to lowercase
        df[c] = s

# Standardizing column names
    if normalize_columns:
        df.columns = (
            df.columns
            .str.strip()
            .str.lower()
            .str.replace(" ", "_")
        )
    return df

customer_df1 = standardize_text(customer_df1)
customer_df2 = standardize_text(customer_df2)
customer_df3 = standardize_text(customer_df3)

# %%
#Check the type of the variables of the df
customer_df1.dtypes
# Out:
# customer                     string[python]
# st                           string[python]
# gender                       string[python]
# education                    string[python]
# customer_lifetime_value      string[python]
# income                              float64
# monthly_premium_auto                float64
# number_of_open_complaints    string[python]
# policy_type                  string[python]
# vehicle_class                string[python]
# total_claim_amount                  float64
# dtype: object

# %%
#Check the type of the variables of the df
customer_df2.dtypes
# Out:
# customer                     string[python]
# st                           string[python]
# gender                       string[python]
# education                    string[python]
# customer_lifetime_value      string[python]
# income                                int64
# monthly_premium_auto                  int64
# number_of_open_complaints    string[python]
# total_claim_amount                  float64
# policy_type                  string[python]
# vehicle_class                string[python]
# dtype: object

# %%
# Check the type of the variables of the df
customer_df3.dtypes
# Out:
# customer                     string[python]
# state                        string[python]
# customer_lifetime_value             float64
# education                    string[python]
# gender                       string[python]
# income                                int64
# monthly_premium_auto                  int64
# number_of_open_complaints             int64
# policy_type                  string[python]
# total_claim_amount                  float64
# vehicle_class                string[python]
# dtype: object

# %%
# Standardise the column names: `st` is replaced for `state`
# Ensure that col names are the same between dfs

customer_df1.rename(columns={"st": "state"}, inplace = True)
customer_df1.head(2)
# Out:
#   customer       state gender education customer_lifetime_value  income  \
# 0  rb50392  washington   <NA>    master                    <NA>    0.00
# 1  qz44356     arizona      f  bachelor              697953.59%    0.00
#
#    monthly_premium_auto number_of_open_complaints    policy_type  \
# 0              1,000.00                    1/0/00  personal auto
# 1                 94.00                    1/0/00  personal auto
#
#    vehicle_class  total_claim_amount
# 0  four-door car                2.70
# 1  four-door car            1,131.46

# %%
# Standardise the column names: `st` is replaced for `state`

customer_df2.rename(columns={"st": "state"}, inplace = True)
customer_df2.head(2)
# Out:
#   customer       state gender education customer_lifetime_value  income  \
# 0  gs98873     arizona      f  bachelor              323912.47%   16061
# 1  cw49887  california      f    master              462680.11%   79487
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00              633.60
# 1                   114                    1/0/00              547.20
#
#      policy_type  vehicle_class
# 0  personal auto  four-door car
# 1   special auto            suv

# %% [markdown]
# ### Vertical concatenation

# %%
# Vertical concatenation is used to add more rows;
# ignore_index=True, to create a new index for the combined df, ignoring the original indexes

customer_concat = pd.concat([customer_df1, customer_df2, customer_df3], axis=0, ignore_index=True)
customer_concat.shape
# Out:
# (12074, 11)

# %% [markdown]
# #### Clean and format the new df

# %% [markdown]
# #### Formatting data types

# %%
# Format data types of "customer lifetime value" that should be numeric
# cleansing inconsistent values of "customer_lifetime_value"

customer_concat["customer_lifetime_value"] = (
    customer_concat["customer_lifetime_value"]
    .astype("string")                       # ensure string dtype
    .fillna("")                             # temporarily replace <NA> with empty string
    .str.replace('%', '', regex=False)      # remove percent signs
    .str.strip()                            # remove leading/trailing spaces
)

# Convert to numeric safely; non-convertible values become NaN
customer_concat["customer_lifetime_value"] = pd.to_numeric(
    customer_concat["customer_lifetime_value"],
    errors="coerce"
)
customer_concat["customer_lifetime_value"].dtype
customer_concat.dtypes
# Out:
# customer                     string[python]
# state                        string[python]
# gender                       string[python]
# education                    string[python]
# customer_lifetime_value             Float64
# income                              float64
# monthly_premium_auto                float64
# number_of_open_complaints            object
# policy_type                  string[python]
# vehicle_class                string[python]
# total_claim_amount                  float64
# dtype: object

# %%
customer_concat["customer_lifetime_value"].describe
customer_concat.isna().sum()
# Out:
# customer                     2937
# state                        2937
# gender                       3059
# education                    2937
# customer_lifetime_value      2944
# income                       2937
# monthly_premium_auto         2937
# number_of_open_complaints    2937
# policy_type                  2937
# vehicle_class                2937
# total_claim_amount           2937
# dtype: int64

# %%
# "number of open complaints" has an incorrect format. 
# Look at the different values it takes with `unique()` and take the middle value. 
customer_concat["number_of_open_complaints"].unique()

# As an example, 1/5/00 should be 5. Number of open complaints is a string
# you can use `split()` to deal with it and take the number you need. 
# Finally, since it should be numeric, cast the column to be in its proper type.
# Ensure the column is a string
customer_concat["number_of_open_complaints"] = customer_concat["number_of_open_complaints"].astype("string")

# Split by '/' and take the middle value (index 1)
customer_concat["number_of_open_complaints"] = customer_concat["number_of_open_complaints"].str.split('/').str[1]

# Convert to numeric (Int64 allows for missing values)
customer_concat["number_of_open_complaints"] = pd.to_numeric(
    customer_concat["number_of_open_complaints"],
    errors="coerce"
).astype("Int64")

# Check result
print(customer_concat["number_of_open_complaints"].unique())
print(customer_concat["number_of_open_complaints"].dtype)
# Out:
# <IntegerArray>
# [0, 2, 1, 3, 5, 4, <NA>]
# Length: 7, dtype: Int64
# Int64

# %%
customer_concat["customer_lifetime_value"].describe
customer_concat.isna().sum()
# Out:
# customer                      2937
# state                         2937
# gender                        3059
# education                     2937
# customer_lifetime_value       2944
# income                        2937
# monthly_premium_auto          2937
# number_of_open_complaints    10007
# policy_type                   2937
# vehicle_class                 2937
# total_claim_amount            2937
# dtype: int64

# %%
# Check categories of nominal var "state"
customer_concat["state"].drop_duplicates()
# Out:
# 0       washington
# 1          arizona
# 2           nevada
# 3       california
# 5           oregon
# 17            cali
# 28              az
# 65              wa
# 1071          <NA>
# Name: state, dtype: string

# %%
# Check categories of nominal var "gender"
customer_concat["gender"].drop_duplicates()
# Out:
# 0        <NA>
# 1           f
# 3           m
# 154     femal
# 231      male
# 297    female
# Name: gender, dtype: string

# %%
# Check categories of nominal var "education"
customer_concat["education"].drop_duplicates()
# Out:
# 0                     master
# 1                   bachelor
# 4       high school or below
# 6                    college
# 21                 bachelors
# 44                    doctor
# 1071                    <NA>
# Name: education, dtype: string

# %%
# Check categories of nominal var "vehicle_class"
customer_concat["vehicle_class"].drop_duplicates()
# Out:
# 0       four-door car
# 2        two-door car
# 3                 suv
# 31         luxury suv
# 43         sports car
# 79         luxury car
# 1071             <NA>
# Name: vehicle_class, dtype: string

# %%
# Cleansing inconsistent values (cleaning inconsistent names of categories) of "state"
customer_concat["state"] = customer_concat["state"].map({"cali": "california", "az": "arizona", "wa": "washington"}).fillna(customer_concat["state"])

# Cleansing inconsistent values (cleaning inconsistent names of categories) of "gender"
customer_concat["gender"] = customer_concat["gender"].map({"F": "f", "femal": "f", "female": "f", "male": "m"}).fillna(customer_concat["gender"])

# Cleansing inconsistent values (cleaning inconsistent names of categories) of "education"
customer_concat["education"] = customer_concat["education"].map({"bachelors": "bachelor"}).fillna(customer_concat["education"])

# Cleansing inconsistent values (cleaning inconsistent names of categories) of "vehicle_class"
customer_concat["vehicle_class"] = customer_concat["vehicle_class"].map({"sports car": "luxury", "luxury suv": "luxury", "luxury car": "luxury",}).fillna(customer_concat["vehicle_class"])

# %%
# Check categories of nominal var "state" after cleansing
customer_concat["state"].drop_duplicates()
# Out:
# 0       washington
# 1          arizona
# 2           nevada
# 3       california
# 5           oregon
# 1071          <NA>
# Name: state, dtype: object

# %%
# Check categories of nominal var "gender" after cleansing
customer_concat["gender"].drop_duplicates()
# Out:
# 0    <NA>
# 1       f
# 3       m
# Name: gender, dtype: object

# %%
# Check categories of nominal var "education" after cleansing
customer_concat["education"].drop_duplicates()
# Out:
# 0                     master
# 1                   bachelor
# 4       high school or below
# 6                    college
# 44                    doctor
# 1071                    <NA>
# Name: education, dtype: object

# %%
# Check categories of nominal var "vehicle_class" after cleansing
customer_concat["vehicle_class"].drop_duplicates()
# Out:
# 0       four-door car
# 2        two-door car
# 3                 suv
# 31             luxury
# 1071             <NA>
# Name: vehicle_class, dtype: object

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
import pandas as pd

# # Load file marketing_customer_analysis.csv from an insurance company
url4 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
df_marketing = pd.read_csv(url4, index_col=0) # first column is an index

# Define how floats are formatted when displayed with the string formatting function: '{:,.2f}'.format
# , → adds a thousands separator (e.g., 1,000 instead of 1000)
# .2f → rounds numbers to two decimal places
pd.options.display.float_format = '{:,.2f}'.format

df_marketing.head(4)
# Out:
#            customer       state  customer_lifetime_value response  coverage  \
# unnamed:_0
# 0           DK49336     Arizona                 4,809.22       No     Basic
# 1           KX64629  California                 2,228.53       No     Basic
# 2           LZ68649  Washington                14,947.92       No     Basic
# 3           XL78013      Oregon                22,332.44      Yes  Extended
#
#            education effective_to_date employmentstatus gender  income  ...  \
# unnamed:_0                                                              ...
# 0            College        2011-02-18         Employed      M   48029  ...
# 1            College        2011-01-18       Unemployed      F       0  ...
# 2           Bachelor        2011-02-10         Employed      M   22139  ...
# 3            College        2011-01-11         Employed      M   49078  ...
#
#            number_of_policies     policy_type        policy  renew_offer_type  \
# unnamed:_0
# ...

# %%
# Normalize text columns (strip spaces, set lowercase)

# Parameters:
# df : DataFrame
# cols : columns to normalize; if None, all object/string columns
# lower : convert to lowercase
# strip : strip leading/trailing whitespace
# normalize_columns: normalize column names (strip, lower, replace spaces with _)

# Returns:
# DataFrame (same object, modified in place style but returns df for chaining)


from typing import Optional, Iterable
def standardize_text(
    df: pd.DataFrame,
    cols: Optional[Iterable[str]] = None,
    lower: bool = True,
    strip: bool = True,
    normalize_columns: bool = True,
) -> pd.DataFrame:
       
# Standardizing string values (inside the cells)
    if cols is None:
        cols = df.select_dtypes(include=["object", "string"]).columns  # all object/string columns
    for c in cols:
        s = df[c].astype("string")  # ensure string dtype
        if strip:
            s = s.str.strip()  # removes leading/trailing spaces
        if lower:
            s = s.str.lower()  # convert to lowercase
        df[c] = s

# Standardizing column names
    if normalize_columns:
        df.columns = (
            df.columns
            .str.strip()
            .str.lower()
            .str.replace(" ", "_")
        )
    return df

df_marketing = standardize_text(df_marketing)

# %%
# Convert quantitative variable from string to numeric
# If a value cannot be converted to a number, replace it with NaN (missing value): errors='coerce'
numeric_cols = ['customer_lifetime_value', 'income', 'monthly_premium_auto', 
                'months_since_last_claim', 'months_since_policy_inception',
                'number_of_open_complaints', 'number_of_policies', 'total_claim_amount']
for col in numeric_cols:
    df_marketing[col] = pd.to_numeric(df_marketing[col].astype(str).str.replace('%','', regex=False).str.strip(), errors='coerce')

# %%
# Extract middle value from "number_of_open_complaints" (X/Y/Z format) 
df_marketing['number_of_open_complaints'] = df_marketing['number_of_open_complaints'].astype("string").str.split('/').str[1]
df_marketing['number_of_open_complaints'] = pd.to_numeric(df_marketing['number_of_open_complaints'], errors='coerce').astype("Int64")

# %%
# Convert date columns
df_marketing['effective_to_date'] = pd.to_datetime(df_marketing['effective_to_date'], errors='coerce')

# %%
df_marketing.dtypes
# Out:
# customer                         string[python]
# state                            string[python]
# customer_lifetime_value                 float64
# response                         string[python]
# coverage                         string[python]
# education                        string[python]
# effective_to_date                datetime64[ns]
# employmentstatus                 string[python]
# gender                           string[python]
# income                                    int64
# location_code                    string[python]
# marital_status                   string[python]
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints                 Int64
# number_of_policies                        int64
# policy_type                      string[python]
# policy                           string[python]
# renew_offer_type                 string[python]
# ...

# %%
df_marketing.columns = df_marketing.columns.str.strip().str.lower().str.replace(' ', '_')

# List of categorical variables
categorical_col = [
    'customer',
    'state',
    'response',
    'coverage',
    'education',
    'employmentstatus',  
    'gender',
    'location_code',
    'marital_status',
    'policy_type',
    'policy',
    'renew_offer_type',
    'sales_channel',
    'vehicle_class',
    'vehicle_size',
    'vehicle_type'
]

# Keep only columns that exist in the DataFrame
categorical_col = [col for col in categorical_col if col in df_marketing.columns]

# Convert all categorical columns to string dtype
for col in categorical_col:
    df_marketing[col] = df_marketing[col].astype('string')

# Print unique values for each categorical column
for col in categorical_col:
    print(f"Unique values for '{col}':")
    print(df_marketing[col].drop_duplicates().tolist())
    print("-" * 50)
# Out:
# Unique values for 'customer':
# ...

# %%
# cleaning inconsistent values (cleaning inconsistent names of categories) of "vehicle_class"
df_marketing["vehicle_class"] = df_marketing["vehicle_class"].map({"sports car": "luxury", "luxury suv": "luxury", "luxury car": "luxury",}).fillna(df_marketing["vehicle_class"])
df_marketing["vehicle_class"].drop_duplicates()
# Out:
# unnamed:_0
# 0    four-door car
# 2              suv
# 7     two-door car
# 8           luxury
# Name: vehicle_class, dtype: object

# %%
# Check NA counts for all categorical columns
for col in categorical_col:
    if col in df_marketing.columns:
        na_count = df_marketing[col].isna().sum()
        total = len(df_marketing)
        pct = (na_count / total) * 100
        print(f"{col}: {na_count} missing values ({pct:.2f}%)")
# Out:
# customer: 0 missing values (0.00%)
# state: 0 missing values (0.00%)
# response: 0 missing values (0.00%)
# coverage: 0 missing values (0.00%)
# education: 0 missing values (0.00%)
# employmentstatus: 0 missing values (0.00%)
# gender: 0 missing values (0.00%)
# location_code: 0 missing values (0.00%)
# marital_status: 0 missing values (0.00%)
# policy_type: 0 missing values (0.00%)
# policy: 0 missing values (0.00%)
# renew_offer_type: 0 missing values (0.00%)
# sales_channel: 0 missing values (0.00%)
# vehicle_class: 0 missing values (0.00%)
# vehicle_size: 0 missing values (0.00%)
# vehicle_type: 0 missing values (0.00%)

# %%
# Change variable name to make it conform to data it contains "gender" -> "sex"
df_marketing = df_marketing.rename(columns={'gender': 'sex'})
categorical_col = [
    'customer',
    'state',
    'response',
    'coverage',
    'education',
    'employmentstatus',  
    'sex',
    'location_code',
    'marital_status',
    'policy_type',
    'policy',
    'renew_offer_type',
    'sales_channel',
    'vehicle_class',
    'vehicle_size',
    'vehicle_type'
]

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
# Bivariate analysis: total revenue by each sales channel
# pivot summary table showing the total revenue for each sales channel (branch, call center, web, and mail)

pivot_sales = (
    df_marketing
    .pivot_table(
        values='total_claim_amount',       # numeric column (revenue)
        index='sales_channel',             # grouping variable
        aggfunc='sum'                      # aggregate by sum of revenue
    )
    .round(2)                              # round to 2 decimal places
    .sort_values(by='total_claim_amount', ascending=False)  # sort high → low
)

# Display results
print(pivot_sales)
# Out:
#                total_claim_amount
# sales_channel
# agent                1,810,226.82
# branch               1,301,204.00
# call center            926,600.82
# web                    706,600.04

# %%
# Ratio of total revenue from Agent to Web
ratio_agent_web = (
    pivot_sales.loc['agent', 'total_claim_amount'] /
    pivot_sales.loc['web', 'total_claim_amount']
)
print(f"Ratio of total revenue from Agent to Web: {ratio_agent_web:.2f}")
# Out:
# Ratio of total revenue from Agent to Web: 2.56

# %% [markdown]
# #### Results
# - The Agent sales channel generated the highest total revenue, followed by Branch, Call Center, and Web.
# - The ratio of total revenue from Agent to Web is 2.56, indicating that the Agent channel brought in about 2.6 times more revenue than Web.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
# Bivariate analysis: average customer lifetime value by gender and education level (gender was renamed to sex)
# pivot summary table showing the average customer lifetime value by gender and education level

pivot_customer_lifetime_value = (
    df_marketing
    .pivot_table(
        values='customer_lifetime_value',   # numeric variable
        index='sex',                     # row grouping
        columns='education',                # column grouping
        aggfunc='mean'                      # average (mean)
    )
    .round(2)                               # round to 2 decimals
)

# Display results
print(pivot_customer_lifetime_value)
# Out:
# education  bachelor  college   doctor  high school or below   master
# sex
# f          7,874.27 7,748.82 7,328.51              8,675.22 8,157.05
# m          7,703.60 8,052.46 7,415.33              8,149.69 8,168.83

# %% [markdown]
# #### Results
# - Customers with a doctorate degree show lower average customer lifetime value than those in other education categories.
# - The average customer lifetime value is generally similar between male and female customers across most education levels.
# - However, a notable divergence appears among customers with a high school or below education, where female customers report a higher average lifetime value compared to males.
# - This suggests that sex differences in lifetime value may become more pronounced in lower education segments, while remaining relatively stable in higher education groups.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# "number of open complaints" has an incorrect format. 
# Look at the different values it takes with `unique()` and take the middle value. 
df_marketing["number_of_open_complaints"].unique()

# As an example, 1/5/00 should be 5. Number of open complaints is a string
# you can use `split()` to deal with it and take the number you need. 
# Finally, since it should be numeric, cast the column to be in its proper type.
# Ensure the column is a string
df_marketing["number_of_open_complaints"] = df_marketing["number_of_open_complaints"].astype("string")

# Split by '/' and take the middle value (index 1)
df_marketing["number_of_open_complaints"] = df_marketing["number_of_open_complaints"].str.split('/').str[1]

# Convert to numeric (Int64 allows for missing values)
df_marketing["number_of_open_complaints"] = pd.to_numeric(
    df_marketing["number_of_open_complaints"],
    errors="coerce"
).astype("Int64")

# Check result
print(df_marketing["number_of_open_complaints"].unique())
print(df_marketing["number_of_open_complaints"].dtype)
# Out:
# <IntegerArray>
# [<NA>]
# Length: 1, dtype: Int64
# Int64

# %%
print(df_marketing['number_of_open_complaints'].head(10))
# Out:
# unnamed:_0
# 0    <NA>
# 1    <NA>
# 2    <NA>
# 3    <NA>
# 4    <NA>
# 5    <NA>
# 6    <NA>
# 7    <NA>
# 8    <NA>
# 9    <NA>
# Name: number_of_open_complaints, dtype: Int64

# %%
# Extract month name from "effective_to_date" into a new column "month"
df_marketing['month'] = df_marketing['effective_to_date'].dt.month_name()


# Total number of complaints by policy type category over time in months
complaints_by_policy_month = (
    df_marketing
    .groupby(['policy_type', 'month'], as_index=False)
    ["number_of_open_complaints"]
    .sum()
)

# Sort for readability
complaints_by_policy_month = complaints_by_policy_month.sort_values(['policy_type', 'month'])

print(complaints_by_policy_month)
# Out:
#       policy_type     month  number_of_open_complaints
# 0  corporate auto  February                          0
# 1  corporate auto   January                          0
# 2   personal auto  February                          0
# 3   personal auto   January                          0
# 4    special auto  February                          0
# 5    special auto   January                          0
